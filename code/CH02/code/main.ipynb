# %%
import numpy as np
from scipy.stats import beta
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})

# %%
x = np.linspace(0, 1, 100)

# %%
# params = [
#     (0.5, 0.5),
#     (1, 1),
#     (4, 3),
#     (2, 5),
#     (6, 6)
# ]

# %%
rng = np.random.default_rng(seed=12345)
np_params = rng.random(10).reshape((5, 2))

# %%
# temp = np.array(np_params)
# temp.shape

# %%
# np_params

# %%
params = list(np_params)
params
# Out:
# [array([0.22733602, 0.31675834]),
#  array([0.79736546, 0.67625467]),
#  array([0.39110955, 0.33281393]),
#  array([0.59830875, 0.18673419]),
#  array([0.67275604, 0.94180287])]

# %%
for p in params:
    print(p[0], p[1])
    y = beta.pdf(x, p[0], p[1])
    plt.plot(x, y, label=f"$\\alpha={p[0]}$, $\\beta={p[1]}$")
plt.xlabel("$\\theta$, Fairness")
plt.ylabel("Density")
plt.legend(title="Parameters")
plt.show()
# Out:
# 0.22733602246716966 0.31675833970975287
# 0.7973654573327341 0.6762546707509746
# 0.391109550601909 0.33281392786638453
# 0.5983087535871898 0.18673418560371335
# 0.6727560440146213 0.9418028652699372
